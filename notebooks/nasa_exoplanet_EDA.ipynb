# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaua281/nasa-exoplanet-analysis/blob/main/notebooks/nasa_exoplanet_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The NASA Exoplanet Archive is a database that contains information on all known exoplanets (planets outside our solar system) discovered by NASA's various space missions, ground-based observatories, and other sources. The dataset includes information such as the planet's name, mass, radius, distance from its host star, orbital period, and other physical characteristics. The dataset also includes information on the host star, such as its name, mass, and radius. The archive is updated regularly as new exoplanets are discovered, and it is a valuable resource for astronomers studying the properties and distribution of exoplanets in our galaxy.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/cleaned_5250.csv")

# %%
dictionary = {
    'Column': [
        'Name',
        'Distance',
        'Stellar_magnitude',
        'Planet_type',
        'Discovery_year',
        'Mass_multiplier',
        'Mass_wrt',
        'Radius_multiplier',
        'Radius_wrt',
        'Orbital_radius',
        'Orbital_period',
        'Eccentricity',
        'Detection_method'
    ],
    'Description': [
        'Name of the planet as per given by NASA.',
        'Distance of the planet from earth in light years.',
        'Brightness of the planet, the brighter the planet the lower number is assigned to the planet.',
        'Type of the planet, these types are derived from our solar system planets.',
        'Year in which planet got discovered.',
        'Mass multiplier of the planet with mass_wrt planet.',
        'Mass of the planet in comparison with the mass of planets of our solar system.',
        'Radius multiplier of the planet with radius_wrt planet.',
        'Radius of the planet in comparison with the radius of planets of our solar system.',
        'Orbital radius of planets orbiting around their sun (in AU).',
        'Time in years taken by those planets to complete 1 orbit of their star',
        'Eccentricity basically tells how circular is the orbitting path, eccentricity close to 0 means orbitting path is nearly circular',
        'Method used by NASA to find that exoplanet'
    ],
}
df_dicionario = pd.DataFrame(dictionary)
pd.set_option('display.max_colwidth', None)

display(df_dicionario)
# Out:
#                Column  \
# 0                Name
# 1            Distance
# 2   Stellar_magnitude
# 3         Planet_type
# 4      Discovery_year
# 5     Mass_multiplier
# 6            Mass_wrt
# 7   Radius_multiplier
# 8          Radius_wrt
# 9      Orbital_radius
# 10     Orbital_period
# 11       Eccentricity
# 12   Detection_method
#
#                                                                                                                          Description
# 0                                                                                           Name of the planet as per given by NASA.
# 1                                                                                  Distance of the planet from earth in light years.
# 2                                      Brightness of the planet, the brighter the planet the lower number is assigned to the planet.
# ...

# %%
display(df.describe())
# Out:
#            distance  stellar_magnitude  discovery_year  mass_multiplier  \
# count   5233.000000        5089.000000     5250.000000      5227.000000
# mean    2167.168737          12.683738     2015.732190         6.434812
# std     3245.522087           3.107571        4.307336        12.972727
# min        4.000000           0.872000     1992.000000         0.020000
# 25%      389.000000          10.939000     2014.000000         1.804000
# 50%     1371.000000          13.543000     2016.000000         4.170140
# 75%     2779.000000          15.021000     2018.000000         8.000000
# max    27727.000000          44.610000     2023.000000       752.000000
#
#        radius_multiplier  orbital_radius  orbital_period  eccentricity
# count        5233.000000     4961.000000    5.250000e+03   5250.000000
# mean            1.015121        6.962942    4.791509e+02      0.063568
# std             0.603479      138.673600    1.680445e+04      0.141424
# ...

# %%
df.head(5)
# Out:
#                    name  distance  stellar_magnitude planet_type  \
# 0  11 Comae Berenices b     304.0            4.72307   Gas Giant
# 1    11 Ursae Minoris b     409.0            5.01300   Gas Giant
# 2       14 Andromedae b     246.0            5.23133   Gas Giant
# 3         14 Herculis b      58.0            6.61935   Gas Giant
# 4          16 Cygni B b      69.0            6.21500   Gas Giant
#
#    discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# 0            2007         19.40000  Jupiter               1.08    Jupiter
# 1            2009         14.74000  Jupiter               1.09    Jupiter
# 2            2008          4.80000  Jupiter               1.15    Jupiter
# 3            2002          8.13881  Jupiter               1.12    Jupiter
# 4            1996          1.78000  Jupiter               1.20    Jupiter
#
#    orbital_radius  orbital_period  eccentricity detection_method
# ...
